# %%
import ollama
ollama.list().model_dump()
# Out:
# {'models': [{'model': 'gemma3:12b-it-q8_0',
#    'modified_at': datetime.datetime(2025, 12, 14, 21, 56, 48, 581568, tzinfo=TzInfo(-06:00)),
#    'digest': '997a7c2c09753e9011ec18a3fcb498e27c0ba330599dfb26a2e05b58cfbdc1bc',
#    'size': 13362620011,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'gemma3',
#     'families': ['gemma3'],
#     'parameter_size': '12.2B',
#     'quantization_level': 'Q8_0'}},
#   {'model': 'qwen3:30b-a3b-instruct-2507-q4_K_M',
#    'modified_at': datetime.datetime(2025, 12, 11, 0, 9, 12, 434512, tzinfo=TzInfo(-06:00)),
#    'digest': '19e422b0231392335cfc49cfd172de7034bb1aeabb08aa307cce745c60b272fe',
#    'size': 18556699186,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'qwen3moe',
#     'families': ['qwen3moe'],
#     'parameter_size': '30.5B',
#     'quantization_level': 'Q4_K_M'}},
#   {'model': 'deepseek-r1:32b',
#    'modified_at': datetime.datetime(2025, 12, 11, 0, 3, 46, 95359, tzinfo=TzInfo(-06:00)),
#    'digest': 'edba8017331d15236e57480eb45406c0d721db77a4cdcf234df500fc2ad3960c',
#    'size': 19851337809,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'qwen2',
#     'families': ['qwen2'],
#     'parameter_size': '32.8B',
#     'quantization_level': 'Q4_K_M'}},
#   {'model': 'ministral-3:14b-instruct-2512-q8_0',
#    'modified_at': datetime.datetime(2025, 12, 10, 23, 42, 46, 719471, tzinfo=TzInfo(-06:00)),
#    'digest': 'd208c26ca3b6a252517783882c0b4638fca1976b43a2fee7bcbeadc51e4c84b8',
#    'size': 15214281951,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'mistral3',
#     'families': ['mistral3'],
#     'parameter_size': '13.9B',
#     'quantization_level': 'Q8_0'}},
#   {'model': 'hf.co/unsloth/Qwen3-32B-GGUF:latest',
#    'modified_at': datetime.datetime(2025, 8, 30, 2, 52, 32, 372570, tzinfo=TzInfo(-05:00)),
#    'digest': '77e7d26c05df9acac668c43ac2f3f6f2545110ae0ad88ec0bc48c93ea5e6675a',
#    'size': 19762152260,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'qwen3',
#     'families': ['qwen3'],
#     'parameter_size': '32.8B',
#     'quantization_level': 'unknown'}},
#   {'model': 'hf.co/TheDrummer/Cydonia-24B-v4.1-GGUF:latest',
#    'modified_at': datetime.datetime(2025, 8, 29, 22, 6, 41, 435691, tzinfo=TzInfo(-05:00)),
#    'digest': '412d441fd4e070e2d042eeaa22f374fd42cb7b3147e091df3e1a5fb571968214',
#    'size': 14333911314,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'llama',
#     'families': ['llama'],
#     'parameter_size': '23.6B',
#     'quantization_level': 'unknown'}},
#   {'model': 'hf.co/unsloth/gpt-oss-20b-GGUF:latest',
#    'modified_at': datetime.datetime(2025, 8, 29, 18, 3, 41, 891934, tzinfo=TzInfo(-05:00)),
#    'digest': '779e997d7f03242ec95b02308c1b72a442a720dbc16abf5f0c63cac845e5e5a4',
#    'size': 11624767550,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'gpt-oss',
#     'families': ['gpt-oss'],
#     'parameter_size': '20.9B',
#     'quantization_level': 'unknown'}},
#   {'model': 'gpt-oss:latest',
#    'modified_at': datetime.datetime(2025, 8, 29, 17, 16, 12, 741339, tzinfo=TzInfo(-05:00)),
#    'digest': 'aa4295ac10c3afb60e6d711289fc6896f5aef82258997b9efdaed6d0cc4cd8b8',
#    'size': 13780173724,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'gptoss',
#     'families': ['gptoss'],
#     'parameter_size': '20.9B',
#     'quantization_level': 'MXFP4'}},
#   {'model': 'qwen3:30b-a3b-instruct-2507-q8_0',
#    'modified_at': datetime.datetime(2025, 8, 29, 15, 28, 34, 973351, tzinfo=TzInfo(-05:00)),
#    'digest': '0835cef7f5cab6524fb3b2f4ca2fb95fd7e86d908ac897c679d49230b042402c',
#    'size': 32483944999,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'qwen3moe',
#     'families': ['qwen3moe'],
#     'parameter_size': '30.5B',
#     'quantization_level': 'Q8_0'}},
#   {'model': 'qwen3:4b-instruct-2507-fp16',
#    'modified_at': datetime.datetime(2025, 8, 28, 22, 1, 3, 324556, tzinfo=TzInfo(-05:00)),
#    'digest': '2ec9fc47b45592e7be1ae5fb0d435e90aaabc45dbe58bea02de8cbb078e413ee',
#    'size': 8051298239,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'qwen3',
#     'families': ['qwen3'],
#     'parameter_size': '4.0B',
#     'quantization_level': 'F16'}},
#   {'model': 'qwen3:latest',
#    'modified_at': datetime.datetime(2025, 8, 28, 21, 59, 27, 364865, tzinfo=TzInfo(-05:00)),
#    'digest': '500a1f067a9f782620b40bee6f7b0c89e17ae61f686b92c24933e4ca4b2b8b41',
#    'size': 5225388164,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'qwen3',
#     'families': ['qwen3'],
#     'parameter_size': '8.2B',
#     'quantization_level': 'Q4_K_M'}},
#   {'model': 'gemma2:9b-instruct-q8_0',
#    'modified_at': datetime.datetime(2025, 8, 24, 15, 22, 34, 573295, tzinfo=TzInfo(-05:00)),
#    'digest': '54faa8324fdf5138279b835f87f39c30db7a534b4211fabad80e476ddbd9e409',
#    'size': 9827158561,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'gemma2',
#     'families': ['gemma2'],
#     'parameter_size': '9.2B',
#     'quantization_level': 'Q8_0'}},
#   {'model': 'gemma3:27b-it-q4_K_M',
#    'modified_at': datetime.datetime(2025, 8, 17, 20, 58, 1, 857939, tzinfo=TzInfo(-05:00)),
#    'digest': 'a418f5838eaf7fe2cfe0a3046c8384b68ba43a4435542c942f9db00a5f342203',
#    'size': 17396936941,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'gemma3',
#     'families': ['gemma3'],
#     'parameter_size': '27.4B',
#     'quantization_level': 'Q4_K_M'}},
#   {'model': 'gemma3:27b',
#    'modified_at': datetime.datetime(2025, 8, 14, 23, 18, 52, 165622, tzinfo=TzInfo(-05:00)),
#    'digest': 'a418f5838eaf7fe2cfe0a3046c8384b68ba43a4435542c942f9db00a5f342203',
#    'size': 17396936941,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'gemma3',
#     'families': ['gemma3'],
#     'parameter_size': '27.4B',
#     'quantization_level': 'Q4_K_M'}},
#   {'model': 'hf.co/Qwen/Qwen3-Embedding-8B-GGUF:latest',
#    'modified_at': datetime.datetime(2025, 8, 14, 23, 3, 19, 191167, tzinfo=TzInfo(-05:00)),
#    'digest': '0be370f86d7da76c7b8f9f1acc26205f1b0aa756ba57e88490a70d0587247053',
#    'size': 4676806979,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'qwen3',
#     'families': ['qwen3'],
#     'parameter_size': '7.57B',
#     'quantization_level': 'unknown'}},
#   {'model': 'bge-m3:latest',
#    'modified_at': datetime.datetime(2025, 8, 14, 21, 15, 45, 811655, tzinfo=TzInfo(-05:00)),
#    'digest': '7907646426070047a77226ac3e684fbbe8410524f7b4a74d02837e43f2146bab',
#    'size': 1157672605,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'bert',
#     'families': ['bert'],
#     'parameter_size': '566.70M',
#     'quantization_level': 'F16'}},
#   {'model': 'hf.co/unsloth/gemma-3-27b-it-GGUF:Q4_K_M',
#    'modified_at': datetime.datetime(2025, 3, 22, 22, 7, 39, 631935, tzinfo=TzInfo(-05:00)),
#    'digest': '31943c04b0c2486e9b5a27ca911419f74bee29e478392efd8e92fc3f77fbb09f',
#    'size': 17404428304,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'gemma3',
#     'families': ['gemma3'],
#     'parameter_size': '27B',
#     'quantization_level': 'unknown'}},
#   {'model': 'qwen2.5:latest',
#    'modified_at': datetime.datetime(2025, 3, 8, 19, 15, 0, 176154, tzinfo=TzInfo(-06:00)),
#    'digest': '845dbda0ea48ed749caafd9e6037047aa19acfcfd82e704d7ca97d631a0b697e',
#    'size': 4683087332,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'qwen2',
#     'families': ['qwen2'],
#     'parameter_size': '7.6B',
#     'quantization_level': 'Q4_K_M'}},
#   {'model': 'phi4:14b-q8_0',
#    'modified_at': datetime.datetime(2025, 3, 1, 20, 6, 18, 482819, tzinfo=TzInfo(-06:00)),
#    'digest': '310d366232f429f1ee2c38893ae202357d45dfbc7c9926b7352ae95636114c26',
#    'size': 15580501989,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'phi3',
#     'families': ['phi3'],
#     'parameter_size': '14.7B',
#     'quantization_level': 'Q8_0'}},
#   {'model': 'gemma2:27b-instruct-q6_K',
#    'modified_at': datetime.datetime(2025, 3, 1, 18, 15, 46, 384918, tzinfo=TzInfo(-06:00)),
#    'digest': '42dd7dda6a9b9148699dbf04e1463f3d2bf8024963bd133df0444d04f2bc82cb',
#    'size': 22343533698,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'gemma2',
#     'families': ['gemma2'],
#     'parameter_size': '27.2B',
#     'quantization_level': 'Q6_K'}},
#   {'model': 'gemma2:9b-instruct-fp16',
#    'modified_at': datetime.datetime(2025, 3, 1, 18, 12, 49, 15486, tzinfo=TzInfo(-06:00)),
#    'digest': '28e6684b085085f78551db7c96a9daa546161b1da9d055ea01b84cb1163013cf',
#    'size': 18490690080,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'gemma2',
#     'families': ['gemma2'],
#     'parameter_size': '9.2B',
#     'quantization_level': 'F16'}},
#   {'model': 'gemma2:27b-instruct-q5_K_S',
#    'modified_at': datetime.datetime(2025, 3, 1, 18, 12, 7, 355149, tzinfo=TzInfo(-06:00)),
#    'digest': '44414d6eeb994e2dd335c5ce6bb607910c07bb9a216faa2864dbd3ece53cd7b6',
#    'size': 18884215940,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'gemma2',
#     'families': ['gemma2'],
#     'parameter_size': '27.2B',
#     'quantization_level': 'Q5_K_S'}},
#   {'model': 'gemma2:9b-text-fp16',
#    'modified_at': datetime.datetime(2025, 3, 1, 18, 10, 37, 187421, tzinfo=TzInfo(-06:00)),
#    'digest': '71ccbb94da283738a5e55ad64fe6cadcab3967067d6184a504004ee15ca6bf4f',
#    'size': 18490689091,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'gemma2',
#     'families': ['gemma2'],
#     'parameter_size': '9.2B',
#     'quantization_level': 'F16'}},
#   {'model': 'gemma2:27b-text-q6_K',
#    'modified_at': datetime.datetime(2025, 3, 1, 16, 27, 37, 784520, tzinfo=TzInfo(-06:00)),
#    'digest': 'c0d8f9013cd069da07696717a0670ee63636429e344c48a8330a807e8db863d5',
#    'size': 22343532709,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'gemma2',
#     'families': ['gemma2'],
#     'parameter_size': '27.2B',
#     'quantization_level': 'Q6_K'}},
#   {'model': 'qwen2.5:14b',
#    'modified_at': datetime.datetime(2025, 3, 1, 0, 12, 54, 960035, tzinfo=TzInfo(-06:00)),
#    'digest': '7cdf5a0187d5c58cc5d369b255592f7841d1c4696d45a8c8a9489440385b22f6',
#    'size': 8988124069,
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'qwen2',
#     'families': ['qwen2'],
#     'parameter_size': '14.8B',
#     'quantization_level': 'Q4_K_M'}}]}

# %%
from openai import OpenAI
client = OpenAI(
    base_url = 'http://localhost:11434/v1',
    api_key='ollama', # required, but unused
)
model = "gemma3:12b-it-q8_0"

# %% [markdown]
# to run llama.cpp, run this command
# ```
# llama-server --host 127.0.0.1 --port 8080 \
#                 --models-dir $LLAMA_CACHE \
#                 -c 8192 -ngl 99
# ```

# %%
# llama cpp
client = OpenAI(
    base_url="http://localhost:8080/v1", # "http://<Your api-server IP>:port"
    api_key = "sk-no-key-required"
)

model = "unsloth_gemma-3-12b-it-GGUF_gemma-3-12b-it-Q8_0"

# %%
from __future__ import annotations

from typing import Optional, List
from pydantic import BaseModel, Field


class StoryStart(BaseModel):
    """
    You are a sharp, imaginative fiction writer.

    Task:
    - Produce (1) a concise, compelling story premise and (2) the opening paragraph that launches the story.

    Rules:
    - If the user provides ideas, weave them in organically (don’t just repeat them).
    - If the user provides no ideas, invent something fresh with a surprising combination of
      genre, setting, protagonist, conflict, and twist.
    - Premise: 2–5 sentences, stakes + hook, no spoilers.
    - Opening paragraph: 120–180 words, vivid and concrete, minimal clichés, clear POV,
      grounded scene, ends with a soft hook.
    - Tone should follow user preferences; default to PG-13 if none are given.
    - Avoid copying user phrasing verbatim; enrich and reframe.
    - If user ideas conflict, choose one coherent direction and proceed.

    Output only fields that match this schema.
    """
    premise: str = Field(..., description="2–5 sentences. Stakes + hook, no spoilers.")
    opening_paragraph: str = Field(..., description="120–180 words. Vivid, grounded, ends with a soft hook.")


class StoryContinue(BaseModel):
    """
    You are a skilled novelist. Write the next paragraph only.

    Inputs:
    - You will be given the story premise and the story-so-far (either the opening paragraph + latest paragraph,
      or a compact analysis summary). Use them to preserve continuity.

    Rules:
    - Output exactly one paragraph of story prose (no headings, no bullets, no analysis).
    - Preserve continuity: characters, tone, POV, tense, world rules.
    - Length target: ~120–200 words unless told otherwise.
    - Concrete detail, strong verbs, show > tell; minimal clichés.
    - Dialogue (if any) should reveal motive or conflict; avoid summary dumps.
    - End with a soft hook/turn that invites the next paragraph.

    Output only fields that match this schema.
    """
    next_paragraph: str = Field(..., description="Exactly one paragraph of continuation prose.")


class StoryAnalysis(BaseModel):
    """
    You are a story analyst. Produce a succinct “Story-So-Far” handoff so another model can write
    the next paragraph without breaking continuity. Do not write new story prose.

    Inputs:
    - You will be given the story premise and the story text so far (opening paragraph + one or more continuation paragraphs).

    Rules:
    - Extract ground truth only from the provided text/premise. No inventions.
    - Capture continuity anchors: cast, goals, stakes, conflicts, setting rules, POV/tense,
      tone/style markers, motifs, and notable objects.
    - Map causality and current situation.
    - List active threads/hazards: open questions, ticking clocks, contradictions to avoid.
    - Provide 3–5 next-paragraph seeds as beats only (no prose paragraphs).

    Output only fields that match this schema.
    """
    logline: str
    cast: List[str] = Field(default_factory=list, description="Bullets: Name — role/goal/conflict; ties.")
    world_rules: List[str] = Field(default_factory=list, description="Bullets: constraints/rules implied by text.")
    pov_tense_tone: str = Field(..., description="Compact string for POV, tense, and tone/style markers.")
    timeline: List[str] = Field(default_factory=list, description="Bullets: key event → consequence.")
    current_situation: str
    active_threads: List[str] = Field(default_factory=list)
    continuity_landmines: List[str] = Field(default_factory=list)
    ambiguities: List[str] = Field(default_factory=list)
    next_paragraph_seeds: List[str] = Field(..., min_length=3, max_length=5, description="Beats-only options, no prose.")

# %%
# -------------------------
# Example calls (Structured)
# -------------------------

# 1) Start
user_prompt = "let's create a new story no preferences just give me a idea"
start = client.beta.chat.completions.parse(
    model=model,
    response_format=StoryStart,
    messages=[
        {"role": "system", "content": "You are a helpful assistant. Follow the response model docstring."},
        {"role": "user", "content": user_prompt},
    ],
    temperature=2,
).choices[0].message.parsed
start = StoryStart.model_validate(start)

# 2) Continue (using premise + approved story-so-far text)
story_so_far = f"Premise:\n{start.premise}\n\nOpening paragraph:\n{start.opening_paragraph}"
cont = client.beta.chat.completions.parse(
    model=model,
    response_format=StoryContinue,
    messages=[
        {"role": "system", "content": "You are a helpful assistant. Follow the response model docstring."},
        {"role": "user", "content": story_so_far},
    ],
    temperature=0.2,
).choices[0].message.parsed
cont = StoryContinue.model_validate(cont)

# (User edits cont.next_paragraph if desired)

# 3) Analyze (premise + opening + approved next paragraph)
story_text = f"{start.opening_paragraph}\n\n{cont.next_paragraph}"
analysis_input = f"Premise:\n{start.premise}\n\nStory text:\n{story_text}"
analysis = client.beta.chat.completions.parse(
    model=model,
    response_format=StoryAnalysis,
    messages=[
        {"role": "system", "content": "You are a helpful assistant. Follow the response model docstring."},
        {"role": "user", "content": analysis_input},
    ],
    temperature=0.2,
).choices[0].message.parsed
analysis = StoryAnalysis.model_validate(analysis)

# 4) Continue again (using analysis summary instead of full text)
cont2_input = (
    f"Premise:\n{start.premise}\n\n"
    f"Story analysis summary:\n{analysis.model_dump_json(indent=2)}"
)
cont2 = client.beta.chat.completions.parse(
    model=model,
    response_format=StoryContinue,
    messages=[
        {"role": "system", "content": "You are a helpful assistant. Follow the response model docstring."},
        {"role": "user", "content": cont2_input},
    ],
    temperature=0.2,
).choices[0].message.parsed
cont2 = StoryContinue.model_validate(cont2)

# %%
Markdown(str(start.model_dump()))
# Out:
# {'premise': 'A cartographer discovers a previously unknown island while charting a familiar trade route. The island is shrouded in perpetual twilight and seems to defy the laws of physics - distances shift, landmarks disappear and reappear, and time flows unevenly.', 'opening_paragraph': "Elias Thorne had charted the Azure Sea for fifteen years. Every reef, every current, every shifting sandbar was imprinted in his mind. Yet, as the 'Wanderlust' sliced through the water, a smudge appeared on the horizon where no smudge should have been. It wasn’t a storm cloud; it was land—an island, vast and impossible, bathed in the eternal grey of perpetual twilight.  His charts showed only open water. This…this was a ghost on the map, a secret the ocean had guarded for centuries."}
